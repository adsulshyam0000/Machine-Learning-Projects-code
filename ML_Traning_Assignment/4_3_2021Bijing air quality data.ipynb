# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import seaborn as sns

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
from datetime import datetime

import pandas as pd



os.chdir(r'C:\Users\Shyam Adsul\Python codes SSPU\Data sets')

df = pd.read_csv('PRSA_Data_Shunyi.csv')

# %%
def convert_to_date(x):
    return datetime.strptime(x,'%Y %m %d %H')

# %%
aq_df_ = pd.read_csv('PRSA_Data_Shunyi.csv', parse_dates = [['year', 'month', 'day', 'hour']],date_parser=convert_to_date, keep_date_col=True)

# %%
aq_df_.head()
# Out:
#   year_month_day_hour  No  year month day hour  PM2.5  PM10  SO2  NO2     CO  \
# 0 2013-03-01 00:00:00   1  2013     3   1    0    3.0   6.0  3.0  8.0  300.0
# 1 2013-03-01 01:00:00   2  2013     3   1    1   12.0  12.0  3.0  7.0  300.0
# 2 2013-03-01 02:00:00   3  2013     3   1    2   14.0  14.0  NaN  7.0  200.0
# 3 2013-03-01 03:00:00   4  2013     3   1    3   12.0  12.0  3.0  5.0    NaN
# 4 2013-03-01 04:00:00   5  2013     3   1    4   12.0  12.0  3.0  NaN  200.0
#
#      O3  TEMP    PRES  DEWP  RAIN  wd  WSPM station
# 0  44.0  -0.9  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  47.0  -1.1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  22.0  -1.7  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3   NaN  -2.1  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  11.0  -2.4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
def convert_to_date(x):
	return datetime.strptime(x, '%Y %m %d %H')

# %%
aq_df_
# Out:
#       year_month_day_hour     No  year month day hour  PM2.5  PM10   SO2  \
# 0     2013-03-01 00:00:00      1  2013     3   1    0    3.0   6.0   3.0
# 1     2013-03-01 01:00:00      2  2013     3   1    1   12.0  12.0   3.0
# 2     2013-03-01 02:00:00      3  2013     3   1    2   14.0  14.0   NaN
# 3     2013-03-01 03:00:00      4  2013     3   1    3   12.0  12.0   3.0
# 4     2013-03-01 04:00:00      5  2013     3   1    4   12.0  12.0   3.0
# ...                   ...    ...   ...   ...  ..  ...    ...   ...   ...
# 35059 2017-02-28 19:00:00  35060  2017     2  28   19   27.0  72.0   8.0
# 35060 2017-02-28 20:00:00  35061  2017     2  28   20   47.0  55.0  17.0
# 35061 2017-02-28 21:00:00  35062  2017     2  28   21   18.0  28.0   4.0
# 35062 2017-02-28 22:00:00  35063  2017     2  28   22   18.0  20.0   9.0
# 35063 2017-02-28 23:00:00  35064  2017     2  28   23   15.0  22.0  13.0
#
#         NO2      CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
aq_df_.isnull().sum()
# Out:
# year_month_day_hour       0
# No                        0
# year                      0
# month                     0
# day                       0
# hour                      0
# PM2.5                   913
# PM10                    548
# SO2                    1296
# NO2                    1365
# CO                     2178
# O3                     1489
# TEMP                     51
# PRES                     51
# DEWP                     54
# RAIN                     51
# wd                      483
# WSPM                     44
# station                   0
# dtype: int64
