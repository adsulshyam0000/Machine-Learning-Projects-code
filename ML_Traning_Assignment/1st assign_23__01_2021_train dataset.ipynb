# %% [raw]
# Follow these steps
# 1. Do some meaningful visualizations on Data and write down your understanding of data
# 2. Do some statistical tests and check on variance, outliers , correlation etc
# 3.Check in which distribution data is present
# 2. Treat Missing values
# 3. Convert data in normal distribution
# 4. Visualizations after scaling
# 5. Treat Categorical Columns
# 6. Prepare your data with best logical strategies for ML Algorithms.
#
# Note -  1.In these steps multiple errors you will get try to read errors and solve it without changing the sequence of the Project.
# 2.Perform same steps for test and train data and make separate pickle files for both.
# 3. Write step by step challenges you faced, strategies you applied and WHY you opted for a particular strategy in your project.
#
# Deadline for project 25/1/2021

# %% [markdown]
# # Data Understanding

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_theme(style= 'darkgrid') 
import os
import sklearn 
from sklearn import preprocessing
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler


df = pd.read_csv(r'C:\Users\Shyam Adsul\Python codes\SSPU assignments\Offline\1st\dataset\blackFriday_train.csv')

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
df.drop(['User_ID'],axis = 1)
# Out:
#        Product_ID Gender    Age  Occupation City_Category  \
# 0       P00069042      F   0-17          10             A
# 1       P00248942      F   0-17          10             A
# 2       P00087842      F   0-17          10             A
# 3       P00085442      F   0-17          10             A
# 4       P00285442      M    55+          16             C
# ...           ...    ...    ...         ...           ...
# 550063  P00372445      M  51-55          13             B
# 550064  P00375436      F  26-35           1             C
# 550065  P00375436      F  26-35          15             B
# 550066  P00375436      F    55+           1             C
# 550067  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df.fillna(method='ffill')
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
a = df['Product_Category_2'].mean()
b = df['Product_Category_3'].mean()
df1= df.fillna(df[{}'Product_Category_2'].mean(),df['Product_Category_3'].mean())
# Out:
#   File "<ipython-input-12-b8e2a082f869>", line 3
#     df1= df.fillna(df[{}'Product_Category_2'].mean(),df['Product_Category_3'].mean())
#                         ^
# SyntaxError: invalid syntax

# %%
df.fillna(df['Product_Category_3'].mean())

# %%
df.isnull().sum()

# %%
df['Marital_Status'] = df['Marital_Status'].replace(0,'Unmarried')
df['Marital_Status'] = df['Marital_Status'].replace(1,'Married')
#marital status changed from 0,1 to married or unmarried

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years Marital_Status  Product_Category_1  \
# 0                          2      Unmarried                   3
# 1                          2      Unmarried                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200

# %%
df['Gender'] = df['Gender'].replace('F','Female')
df['Gender'] = df['Gender'].replace('M','Male')
df.head(2)     #changed M ->MALE ,F -> Female
# Out:
#    User_ID Product_ID  Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042  Female  0-17          10             A
# 1  1000001  P00248942  Female  0-17          10             A
#
#   Stay_In_Current_City_Years Marital_Status  Product_Category_1  \
# 0                          2      Unmarried                   3
# 1                          2      Unmarried                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200

# %%
df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].replace('4+',4)
df.head(10)
# Out:
#    User_ID Product_ID  Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042  Female   0-17          10             A
# 1  1000001  P00248942  Female   0-17          10             A
# 2  1000001  P00087842  Female   0-17          10             A
# 3  1000001  P00085442  Female   0-17          10             A
# 4  1000002  P00285442    Male    55+          16             C
# 5  1000003  P00193542    Male  26-35          15             A
# 6  1000004  P00184942    Male  46-50           7             B
# 7  1000004  P00346142    Male  46-50           7             B
# 8  1000004   P0097242    Male  46-50           7             B
# 9  1000005  P00274942    Male  26-35          20             A
#
#   Stay_In_Current_City_Years Marital_Status  Product_Category_1  \
# 0                          2      Unmarried                   3
# 1                          2      Unmarried                   1
# 2                          2      Unmarried                  12
# ...

# %%
#checking null Values
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
##  dropping the duplicates from the dataset.
print(df.shape)
df1 = df.drop_duplicates(keep='first')
print(df1.shape)
# Out:
# (550068, 12)
# (550068, 12)

# %%
df1.isnull().values
# Out:
# array([[False, False, False, ...,  True,  True, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ...,  True,  True, False],
#        ...,
#        [False, False, False, ...,  True,  True, False],
#        [False, False, False, ...,  True,  True, False],
#        [False, False, False, ...,  True,  True, False]])

# %%
#categorical data treating
obj_df = df.select_dtypes(include=['object']).copy()

obj_df["Gender"] = obj_df["Gender"].astype('category')
obj_df.dtypes
obj_df["Gender"] = obj_df["Gender"].cat.codes

obj_df.head()
# Out:
#   Product_ID  Gender   Age City_Category Stay_In_Current_City_Years  \
# 0  P00069042       0  0-17             A                          2
# 1  P00248942       0  0-17             A                          2
# 2  P00087842       0  0-17             A                          2
# 3  P00085442       0  0-17             A                          2
# 4  P00285442       1   55+             C                          4
#
#   Marital_Status
# 0      Unmarried
# 1      Unmarried
# 2      Unmarried
# 3      Unmarried
# 4      Unmarried

# %%
# To find out the highest 5 purchase,
df2 = df1.sort_values(by ='Purchase', ascending=False).head()
df2

# below are the 5 highest 5 purchase in descending order.
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 370891  1003160  P00052842   Male  26-35          17             C
# 93016   1002272  P00052842   Male  26-35           0             C
# 87440   1001474  P00052842   Male  26-35           4             A
# 503697  1005596  P00117642   Male  36-45          12             B
# 321782  1001577  P00052842   Male    55+           0             C
#
#        Stay_In_Current_City_Years Marital_Status  Product_Category_1  \
# 370891                          3      Unmarried                  10
# 93016                           1      Unmarried                  10
# 87440                           2        Married                  10
# 503697                          1      Unmarried                  10
# 321782                          1        Married                  10
#
#         Product_Category_2  Product_Category_3  Purchase
# 370891                15.0                 NaN     23961
# ...

# %%
# To find out the highest 5 purchase,
df2 = df1.sort_values(by ='Age', ascending=False).head()
df2

# below are the 5 highest 5 purchase in descending order.
# Out:
#         User_ID Product_ID Gender  Age  Occupation City_Category  \
# 364776  1002092  P00015642   Male  55+           1             B
# 295862  1003618  P00154042   Male  55+          17             A
# 295864  1003618  P00004242   Male  55+          17             A
# 295865  1003618  P00320342   Male  55+          17             A
# 295866  1003618  P00138542   Male  55+          17             A
#
#        Stay_In_Current_City_Years Marital_Status  Product_Category_1  \
# 364776                          4        Married                   8
# 295862                          4        Married                   1
# 295864                          4        Married                   1
# 295865                          4        Married                   1
# 295866                          4        Married                   5
#
#         Product_Category_2  Product_Category_3  Purchase
# 364776                16.0                17.0      5998
# ...

# %% [markdown]
# # Pre visualizations

# %%
sns.scatterplot(x= 'Occupation',data=df)
# Out:
# <AxesSubplot:xlabel='Occupation'>

# %%
sns.boxplot(x='Purchase',palette='rainbow' )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-aca2a6470637> in <module>
# ----> 1 sns.boxplot(x='Purchase',palette='rainbow' )
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2238 ):
#    2239
# -> 2240     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2241                           orient, color, palette, saturation,
#    2242                           width, dodge, fliersize, linewidth)
#
# ...

# %%
sns.displot(df['Occupation'],kde = True,color='red')

# %%
sns.histplot(df['Occupation'],kde = True,color='green')
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='Count'>

# %% [markdown]
# # Standard scaling

# %%
Scaling = StandardScaler()

# %%
Scaling.fit_transform(df1[['Occupation','Stay_In_Current_City_Years','Product_Category_1','Product_Category_2','Product_Category_3','Purchase']])
df4_scaled = pd.DataFrame(df1[['Occupation','Stay_In_Current_City_Years','Product_Category_1','Product_Category_2','Product_Category_3','Purchase']])
df4_scaled
# Out:
#         Occupation Stay_In_Current_City_Years  Product_Category_1  \
# 0               10                          2                   3
# 1               10                          2                   1
# 2               10                          2                  12
# 3               10                          2                  12
# 4               16                          4                   8
# ...            ...                        ...                 ...
# 550063          13                          1                  20
# 550064           1                          3                  20
# 550065          15                          4                  20
# 550066           1                          2                  20
# 550067           0                          4                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# ...

# %%
sns.pairplot(df4_scaled)

# %%
sns.boxplot(data= df,4_scaled,y='Occupation')

# %%
#step 1
#detecting detecting NaN values
#step2 remove NaN value

# %%
#df.dropna(how='all').head() #how='all ' just do when all row have nan then droped

# %%
#data filling
#df.fillna(0) #not optimistic

# %%
#df.fillna(method = 'ffill').tail() #forward fill  upper value copied for next row

# %%
#df.fillna(method= 'bfill') #backward  fill

# %%
#interpolation 
#df.interpolate()

# %%
#df_dropped = df.dropna(inplace= True)

# %%
#df_dropped
