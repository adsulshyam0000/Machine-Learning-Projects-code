# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv(r'C:\\Users\LENOVO\machine_learning\House Price.csv')

# %%
df
# Out:
#         Id  LotFrontage  LotArea Alley  MasVnrArea  1stFlrSF  2ndFlrSF  \
# 0        1         65.0     8450   NaN       196.0       856       854
# 1        2         80.0     9600   NaN         0.0      1262         0
# 2        3         68.0    11250   NaN       162.0       920       866
# 3        4         60.0     9550   NaN         0.0       961       756
# 4        5         84.0    14260   NaN       350.0      1145      1053
# ...    ...          ...      ...   ...         ...       ...       ...
# 1455  1456         62.0     7917   NaN         0.0       953       694
# 1456  1457         85.0    13175   NaN       119.0      2073         0
# 1457  1458         66.0     9042   NaN         0.0      1188      1152
# 1458  1459         68.0     9717   NaN         0.0      1078         0
# 1459  1460         75.0     9937   NaN         0.0      1256         0
#
#       GrLivArea GarageType  GarageArea  SalePrice
# 0          1710     Attchd         548     208500
# ...

# %%
df.drop(['Id','Alley','GarageType'],axis = 1,inplace = True)

# %%
df.isnull().sum()
# Out:
# LotFrontage    259
# LotArea          0
# MasVnrArea       8
# 1stFlrSF         0
# 2ndFlrSF         0
# GrLivArea        0
# GarageArea       0
# SalePrice        0
# dtype: int64

# %%
df.describe()
# Out:
#        LotFrontage        LotArea   MasVnrArea     1stFlrSF     2ndFlrSF  \
# count  1201.000000    1460.000000  1452.000000  1460.000000  1460.000000
# mean     70.049958   10516.828082   103.685262  1162.626712   346.992466
# std      24.284752    9981.264932   181.066207   386.587738   436.528436
# min      21.000000    1300.000000     0.000000   334.000000     0.000000
# 25%      59.000000    7553.500000     0.000000   882.000000     0.000000
# 50%      69.000000    9478.500000     0.000000  1087.000000     0.000000
# 75%      80.000000   11601.500000   166.000000  1391.250000   728.000000
# max     313.000000  215245.000000  1600.000000  4692.000000  2065.000000
#
#          GrLivArea   GarageArea      SalePrice
# count  1460.000000  1460.000000    1460.000000
# mean   1515.463699   472.980137  180921.195890
# std     525.480383   213.804841   79442.502883
# min     334.000000     0.000000   34900.000000
# 25%    1129.500000   334.500000  129975.000000
# ...

# %%
#df['GarageType'].fillna(df['GarageType'].mode()[0],inplace = True)

# %%
df.isnull().sum()
# Out:
# LotFrontage    259
# LotArea          0
# MasVnrArea       8
# 1stFlrSF         0
# 2ndFlrSF         0
# GrLivArea        0
# GarageArea       0
# SalePrice        0
# dtype: int64

# %%
df['LotFrontage'].mean()
# Out:
# 70.04995836802665

# %%
df['LotFrontage'].mode()
# Out:
# 0    60.0
# dtype: float64

# %%
df['LotFrontage'].median()
# Out:
# 69.0

# %%
df['LotFrontage'].fillna(df['LotFrontage'].median(),inplace = True)

# %%
df['MasVnrArea'].fillna(df['MasVnrArea'].mean(),inplace = True)

# %%
df.head()
# Out:
#    LotFrontage   LotArea  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea  \
# 0    -0.220875 -0.207142    0.510015 -0.793434  1.161852   0.370333
# 1     0.460320 -0.091886   -0.572835  0.257140 -0.795163  -0.482512
# 2    -0.084636  0.073480    0.322174 -0.627826  1.189351   0.515013
# 3    -0.447940 -0.096897   -0.572835 -0.521734  0.937276   0.383659
# 4     0.641972  0.375148    1.360826 -0.045611  1.617877   1.299326
#
#    GarageArea  SalePrice
# 0    0.351000   0.347273
# 1   -0.060731   0.007288
# 2    0.631726   0.536154
# 3    0.790804  -0.515281
# 4    1.698485   0.869843

# %%
#df = pd.get_dummies(df,columns = ['GarageType'])

# %%
df
# Out:
#       LotFrontage   LotArea  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea  \
# 0       -0.220875 -0.207142    0.510015 -0.793434  1.161852   0.370333
# 1        0.460320 -0.091886   -0.572835  0.257140 -0.795163  -0.482512
# 2       -0.084636  0.073480    0.322174 -0.627826  1.189351   0.515013
# 3       -0.447940 -0.096897   -0.572835 -0.521734  0.937276   0.383659
# 4        0.641972  0.375148    1.360826 -0.045611  1.617877   1.299326
# ...           ...       ...         ...       ...       ...        ...
# 1455    -0.357114 -0.260560   -0.572835 -0.542435  0.795198   0.250402
# 1456     0.687385  0.266407    0.084610  2.355701 -0.795163   1.061367
# 1457    -0.175462 -0.147810   -0.572835  0.065656  1.844744   1.569647
# 1458    -0.084636 -0.080160   -0.572835 -0.218982 -0.795163  -0.832788
# 1459     0.233255 -0.058112   -0.572835  0.241615 -0.795163  -0.493934
#
#       GarageArea  SalePrice
# 0       0.351000   0.347273
# 1      -0.060731   0.007288
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df_scaled=scaler.fit_transform(df)

# %%
df_scaled
# Out:
# array([[-0.22087509, -0.20714171,  0.51141841, ...,  0.37033344,
#          0.35100032,  0.34727322],
#        [ 0.46031974, -0.09188637, -0.57441047, ..., -0.48251191,
#         -0.06073101,  0.00728832],
#        [-0.08463612,  0.07347998,  0.32306034, ...,  0.51501256,
#          0.63172623,  0.53615372],
#        ...,
#        [-0.1754621 , -0.14781027, -0.57441047, ...,  1.56964722,
#         -1.03391416,  1.07761115],
#        [-0.08463612, -0.08016039, -0.57441047, ..., -0.83278768,
#         -1.09005935, -0.48852299],
#        [ 0.23325479, -0.05811155, -0.57441047, ..., -0.49393395,
#         -0.9216238 , -0.42084081]])

# %%
df = pd.DataFrame(df_scaled,columns = ['LotFrontage','LotArea','MasVnrArea','1stFlrSF','2ndFlrSF','GrLivArea','GarageArea','SalePrice'])

# %%
df
# Out:
#       LotFrontage   LotArea  MasVnrArea  1stFlrSF  2ndFlrSF  GrLivArea  \
# 0       -0.220875 -0.207142    0.511418 -0.793434  1.161852   0.370333
# 1        0.460320 -0.091886   -0.574410  0.257140 -0.795163  -0.482512
# 2       -0.084636  0.073480    0.323060 -0.627826  1.189351   0.515013
# 3       -0.447940 -0.096897   -0.574410 -0.521734  0.937276   0.383659
# 4        0.641972  0.375148    1.364570 -0.045611  1.617877   1.299326
# ...           ...       ...         ...       ...       ...        ...
# 1455    -0.357114 -0.260560   -0.574410 -0.542435  0.795198   0.250402
# 1456     0.687385  0.266407    0.084843  2.355701 -0.795163   1.061367
# 1457    -0.175462 -0.147810   -0.574410  0.065656  1.844744   1.569647
# 1458    -0.084636 -0.080160   -0.574410 -0.218982 -0.795163  -0.832788
# 1459     0.233255 -0.058112   -0.574410  0.241615 -0.795163  -0.493934
#
#       GarageArea  SalePrice
# 0       0.351000   0.347273
# 1      -0.060731   0.007288
# ...

# %%
x = df.drop('SalePrice',axis = 1)

# %%
y = df['SalePrice']

# %%
y
# Out:
# 0       0.347273
# 1       0.007288
# 2       0.536154
# 3      -0.515281
# 4       0.869843
#           ...
# 1455   -0.074560
# 1456    0.366161
# 1457    1.077611
# 1458   -0.488523
# 1459   -0.420841
# Name: SalePrice, Length: 1460, dtype: float64

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.svm import SVR
svr= SVR(C=10)

# %%
svr.fit(x_train, y_train)
# Out:
# SVR(C=10)

# %%
from sklearn.metrics import r2_score
score= r2_score(y_test,svr.predict(x_test))
score
# Out:
# 0.6202685459974941

# %%
df
